# %% [markdown]
# - PYTHON FUNCTION: ✅
#
# Python Functions is a block of statements that return the specific task.
# The idea is to put some commonly or repeatedly done tasks together and make a function so that instead of writing the same code again and again for different inputs, we can do the function calls to reuse code contained in it over and over again

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - **Print()** function also has given output but the datatype is **NON-type**
#
# but **return** has given output with **Exact datatype**

# %%
def ravi():
    print("this is my first function")

# %%
type(ravi())
# Out:
# this is my first function
# NoneType

# %%
ravi()
# Out:
# this is my first function

# %%
"sravani" + "ravi"
# Out:
# 'sravaniravi'

# %%
ravi() + "ravi pro"
# Out:
# this is my first function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ravi() + "ravi pro"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
type(ravi())
# Out:
# this is my first function
# NoneType

# %%
def ramesh():
    return "this is my first function"

# %%
ramesh()
# Out:
# 'this is my first function'

# %%
type(ramesh())
# Out:
# str

# %%
ramesh() +"Ramesh pro"
# Out:
# 'this is my first functionRamesh pro'

# %%
type(ramesh())
# Out:
# str

# %%
# checking list

def ravi1():
    print([1,23])

# %%
ravi1()
# Out:
# [1, 23]

# %%
type(ravi1())
# Out:
# [1, 23]
# NoneType

# %%
def ravi2():
    return [1,23]

# %%
ravi2()
# Out:
# [1, 23]

# %%
type(ravi2())
# Out:
# list

# %%
# checking tuples

def ravi3():
    print((1,23))

# %%
type(ravi3())
# Out:
# (1, 23)
# NoneType

# %%
def ravi4():
    return (1,23)

# %%
type(ravi4())
# Out:
# tuple

# %%
# checking sets

def ravi5():
    print( {1,23})

# %%
type(ravi5())
# Out:
# {1, 23}
# NoneType

# %%
def ravi6():
    return  {1,23}

# %%
type(ravi6())
# Out:
# set

# %%
# checking DICT

def ravi7():
    print( {1:23})

# %%
ravi7()
# Out:
# {1: 23}

# %%
type(ravi7())
# Out:
# {1: 23}
# NoneType

# %%
# checking DICT

def ravi8():
   return  {1:23}

# %%
ravi8()
# Out:
# {1: 23}

# %%
type(ravi8())
# Out:
# dict

# %%
def ravi9():
# Out:
#   Cell In[39], line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
def ravi9():
  pass

# %%
def r1():
    return 5,9,[1,23,8]

# %%
r1()
# Out:
# (5, 9, [1, 23, 8])

# %%
a=r1()

# %%
a
# Out:
# (5, 9, [1, 23, 8])

# %%
def r2() :
      return 5,9,[1,23,8]

# %%
r2()
# Out:
# (5, 9, [1, 23, 8])

# %%
r3=r2()

# %%
r3
# Out:
# (5, 9, [1, 23, 8])

# %%
a,b,c=r2()

# %%
a
# Out:
# 5

# %%
b
# Out:
# 9

# %%
c
# Out:
# [1, 23, 8]

# %%
x = 0
y=5

while x < y:

  print('x is currently: ',x)
  x=x+1
  print()
  print(f"updates x values: {x}")
# Out:
# x is currently:  0
#
# updates x values: 1
# x is currently:  1
#
# updates x values: 2
# x is currently:  2
#
# updates x values: 3
# x is currently:  3
#
# updates x values: 4
# x is currently:  4
#
# updates x values: 5

# %%
def f1():
    x=0
    y=5

    while x < y:
       print(f"updates x values: {x}")
       print('x is currently: ',x)
       x=x+1
print()

# %%
f1()
# Out:
# updates x values: 0
# x is currently:  0
# updates x values: 1
# x is currently:  1
# updates x values: 2
# x is currently:  2
# updates x values: 3
# x is currently:  3
# updates x values: 4
# x is currently:  4

# %%
def ff1(x,y):
    while x < y:
       print(f"updates x values: {x}")
       print('x is currently: ',x)
       x=x+1
print()

# %%
ff1(0,5)
# Out:
# updates x values: 0
# x is currently:  0
# updates x values: 1
# x is currently:  1
# updates x values: 2
# x is currently:  2
# updates x values: 3
# x is currently:  3
# updates x values: 4
# x is currently:  4

# %%
ff1(10,33)
# Out:
# updates x values: 10
# x is currently:  10
# updates x values: 11
# x is currently:  11
# updates x values: 12
# x is currently:  12
# updates x values: 13
# x is currently:  13
# updates x values: 14
# x is currently:  14
# updates x values: 15
# x is currently:  15
# updates x values: 16
# x is currently:  16
# updates x values: 17
# x is currently:  17
# updates x values: 18
# x is currently:  18
# updates x values: 19
# x is currently:  19
# updates x values: 20
# x is currently:  20
# updates x values: 21
# x is currently:  21
# updates x values: 22
# x is currently:  22
# updates x values: 23
# x is currently:  23
# updates x values: 24
# x is currently:  24
# updates x values: 25
# x is currently:  25
# updates x values: 26
# x is currently:  26
# updates x values: 27
# x is currently:  27
# updates x values: 28
# x is currently:  28
# updates x values: 29
# x is currently:  29
# updates x values: 30
# x is currently:  30
# updates x values: 31
# x is currently:  31
# ...

# %%
def f1(x,y):
    

  while x < y:
    print('x is currently: ',x)
    x=x+1
  print()
  print(f"updates x values: {x}")

# %%
f1(0,5)
# Out:
# x is currently:  0
# x is currently:  1
# x is currently:  2
# x is currently:  3
# x is currently:  4
#
# updates x values: 5

# %%
f1(-1,9)
# Out:
# x is currently:  -1
# x is currently:  0
# x is currently:  1
# x is currently:  2
# x is currently:  3
# x is currently:  4
# x is currently:  5
# x is currently:  6
# x is currently:  7
# x is currently:  8
#
# updates x values: 9

# %%
f1(100,300)
# Out:
# x is currently:  100
# x is currently:  101
# x is currently:  102
# x is currently:  103
# x is currently:  104
# x is currently:  105
# x is currently:  106
# x is currently:  107
# x is currently:  108
# x is currently:  109
# x is currently:  110
# x is currently:  111
# x is currently:  112
# x is currently:  113
# x is currently:  114
# x is currently:  115
# x is currently:  116
# x is currently:  117
# x is currently:  118
# x is currently:  119
# x is currently:  120
# x is currently:  121
# x is currently:  122
# x is currently:  123
# x is currently:  124
# x is currently:  125
# x is currently:  126
# x is currently:  127
# x is currently:  128
# x is currently:  129
# x is currently:  130
# x is currently:  131
# x is currently:  132
# x is currently:  133
# x is currently:  134
# x is currently:  135
# x is currently:  136
# x is currently:  137
# x is currently:  138
# x is currently:  139
# x is currently:  140
# x is currently:  141
# x is currently:  142
# ...

# %%
a=[1, 5, 8, 10.1, 19,"Ravi"]
l1 = []
for i in a :
  if type(i) == int:
      l1.append(i)

l1
# Out:
# [1, 5, 8, 19]

# %%
def f2(b) :
    l1 = []
    for i in b :
        if type(i) == int:
            l1.append(i)
    return l1

# %%
u=[1, 5, 8, 10.3, 19,"Ravi"]

# %%
f2(u)
# Out:
# [1, 5, 8, 19]

# %%
b=(1,4,7.9,"r",True,False, 3+6j)


f2(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 b=(1,4,7.9,"r",True,False, 3+6j)
# ----> 4 f2(b)
#
# NameError: name 'f2' is not defined

# %%
def strg_split(st):
    ''' this reversing of string '''
    st1=st.split()
    print("checking string split =",st1)
    st2=st1[::-1]
    print("checking reverse of string = ",st2)
    st3=" ".join(st2)
    print("checking joining of string = ",st3)
    return st3

# %%
a="sriya is crazy girl"

strg_split(a)
# Out:
# checking string split = ['sriya', 'is', 'crazy', 'girl']
# checking reverse of string =  ['girl', 'crazy', 'is', 'sriya']
# checking joining of string =  girl crazy is sriya
# 'girl crazy is sriya'

# %%
def palindrome(strng):
      if strng==strng[::-1]:
        print('palidrome')
      else:
        print("not palidrome")

# %%
a="sirisha"

palindrome(a)
# Out:
# not palidrome

# %%
palindrome("mam")
# Out:
# palidrome

# %%
palindrome('141')
# Out:
# palidrome

# %%
#python program for unique items, removing duplicate items in string i.e only unique items
import pandas as pd


def removeduplicates(string):
  strg=string.lower()
  print(strg)
  string=strg.split()
  print(string)
  return " ".join (pd.unique(string))


ravi= 'Gfg is best Gfg also has Classes now. Classes help understand better'
#ravi.lower()
removeduplicates(ravi)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 #python program for unique items, removing duplicate items in string i.e only unique items
# ----> 2 import pandas as pd
#       5 def removeduplicates(string):
#       6   strg=string.lower()
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# writing unique values
def remove_duplicates(string):
    # Convert the string to lowercase and split it into a list of words
    words = string.lower().split()
    
    # Create an empty list to store unique words
    unique_words = []
    
    # Iterate over the list of words
    for word in words:
        # If the word is not already in the list of unique words, add it
        if word not in unique_words:
            unique_words.append(word)
            
    return unique_words

# %%
avi= 'Gfg is best Gfg also has Classes now. Classes help understand better'
remove_duplicates(avi)
# Out:
# ['gfg',
#  'is',
#  'best',
#  'also',
#  'has',
#  'classes',
#  'now.',
#  'help',
#  'understand',
#  'better']

# %%
 #Find all duplicate characters in string

ravi= 'Gfg is best Gfg also has Classes now. Classes help understand better'
from collections import Counter

def dup(stg):
  stg=stg.split()
  print(stg)
  stg=Counter(stg)
  print(stg)
  for key,value in stg.items():
    if value > 1:
      print(key)

# %%
dup(ravi)
# Out:
# ['Gfg', 'is', 'best', 'Gfg', 'also', 'has', 'Classes', 'now.', 'Classes', 'help', 'understand', 'better']
# Counter({'Gfg': 2, 'Classes': 2, 'is': 1, 'best': 1, 'also': 1, 'has': 1, 'now.': 1, 'help': 1, 'understand': 1, 'better': 1})
# Gfg
# Classes

# %%
 #Find all uniQue characters in string

ravi= 'Gfg is best Gfg also has Classes now. Classes help understand better'
from collections import Counter

def  uni(stg):
  stg=stg.split()
  print(stg)
  stg=Counter(stg)
  print(stg)
  for key,value in stg.items():
    if value == 1:
      print(key)

# %%
uni(ravi)
# Out:
# ['Gfg', 'is', 'best', 'Gfg', 'also', 'has', 'Classes', 'now.', 'Classes', 'help', 'understand', 'better']
# Counter({'Gfg': 2, 'Classes': 2, 'is': 1, 'best': 1, 'also': 1, 'has': 1, 'now.': 1, 'help': 1, 'understand': 1, 'better': 1})
# is
# best
# also
# has
# now.
# help
# understand
# better

# %%
def half_upper(strg):
    half=len(strg)//2
    return strg[:half].lower()+strg[half:].upper()

# %%
test="i am bad boy"

half_upper(test)
# Out:
# 'i am bAD BOY'

# %% [markdown]
# # Docstring for the function

# %%
def odd_even(num): #parameters
    """
    This function checks if a given number is odd or even.
    input: any valid number/integer
    output: odd / even
    Created Date: 1-1-2025
    """
    
    if type(num) == int:
        if num % 2 == 0:
            
            return f"even_number  {num}"
        else:
           
            return f"odd_number  {num}"
    else:
        return "Wrong input"

# %%
odd_even(8) #argments
# Out:
# 'even_number  8'

# %%
print(odd_even.__doc__)
# Out:
#     This function checks if a given number is odd or even.
#     input: any valid number/integer
#     output: odd / even
#     Created Date: 1-1-2025

# %%
print(max.__doc__)
# Out:
# max(iterable, *[, default=obj, key=func]) -> value
# max(arg1, arg2, *args, *[, key=func]) -> value
#
# With a single iterable argument, return its biggest item. The
# default keyword-only argument specifies an object to return if
# the provided iterable is empty.
# With two or more arguments, return the largest argument.

# %% [markdown]
# ### Benefits of using a Function
#
# - Code Modularity
# - Code Readibility
# - Code Reusability

# %%
def caculate_area (length, width):
   """
    Calculate the area of a rectangle.

    Parameters:
    length (float): The length of the rectangle.
    width (float): The width of the rectangle.

    Returns:
    float: The area of the rectangle.
    """
   
   return length*width

def calculate_perimeter(length , width):
    """
    Calculate the perimeter of a rectangle.

    Parameters:
    length (float): The length of the rectangle.
    width (float): The width of the rectangle.

    Returns:
    float: The perimeter of the rectangle.
    """
    return 2*(length+width)

def print_shape (length, width):
    """
    Print the area and perimeter of a rectangle.

    Parameters:
    length (float): The length of the rectangle.
    width (float): The width of the rectangle.
    """
        

    area = caculate_area(length, width)
    perimeter = calculate_perimeter(length, width)
    print(f"Rectangle with length {length} and width {width}:")
    print(f"Area: {area}")
    print(f"Perimeter: {perimeter}")

# %%
print_shape(5,2)
# Out:
# Rectangle with length 5 and width 2:
# Area: 10
# Perimeter: 14

# %% [markdown]
# # Types of Arguments
#
# - Default Argument:A default argument is one that assumes a default value if no value is provided for it when the function is called.
#
# - Positional Argument : A positional argument is an argument passed to a function based on its position in the function call
#
# - Keyword Argument : A keyword argument is an argument passed to a function using the syntax `arg=value`.

# %%
def sum(a,b):
    return a+b

# %%
sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 sum()
#
# TypeError: sum() missing 2 required positional arguments: 'a' and 'b'

# %%
def sum(a=6,b=9):
    return a+b

# %%
sum()
# Out:
# 15

# %%
sum(5)
# Out:
# 14

# %%
def greet(name, message="Hello!"):
    print(f"{message} {name}")

# Function calls
greet("Ravi")  # Uses the default message


greet("john", "Welcome!")  # Custom message
# Out:
# Hello! Ravi
# Welcome! john

# %% [markdown]
# - Positional Argument

# %%
def power(a=2,b=3):
    return a**b

# %%
power(3,3)
# Out:
# 27

# %%
def add(a, b):
    return a + b

# Function calls
print(add(5, 3))  # Output: 8
print(add(2, 4))  # Output: 6
# Out:
# 8
# 6

# %% [markdown]
# - Keyword Argument

# %%
def make_pancake(flour, eggs, milk):
    return f"Mixing {flour}gm of flour, {eggs} eggs, and {milk}ml of milk to make pancakes!"

# Function calls
print(make_pancake(flour=200, eggs=2, milk=300))
print(make_pancake(milk=250, eggs=3, flour=180))  # Arguments in different order
# Out:
# Mixing 200g of flour, 2 eggs, and 300ml of milk to make pancakes!
# Mixing 180g of flour, 3 eggs, and 250ml of milk to make pancakes!

# %% [markdown]
# ## What does this mean *args  and ** Kwargs?
#
# ##  *args:
# When we don't know, how many arguments are going to pass into a function is called *arg
#
# *args are generally used With :list, tuples, strings

# %%
def caculate_area(l,w,h):
    return l*w*h


caculate_area(5,8,9)
# Out:
# 360

# %%
def caculate_area(*args):
    product = 1
    for i in args:
        product = product * i
    
    return product

caculate_area(5,8,9)
# Out:
# 360

# %%
caculate_area(1,2,3,4,6,34,23,14,98,100)
# Out:
# 15449817600

# %%
def sum_all(*args):
    return sum(args)

# Function call
sum_all(1, 3, 2, 32, 323, 232, 32, 32, 323, 7)
# Out:
# 987

# %%
def f3(*args):
  return (1, 2, 4, 5, [1, 4, 6], (8, 9), {'a': 7})

# %%
f3()
# Out:
# (1, 2, 4, 5, [1, 4, 6], (8, 9), {'a': 7})

# %%
def f4(*b):
  return 1,2,4,5,[1,4,6],(8,9)

# %%
f4()
# Out:
# (1, 2, 4, 5, [1, 4, 6], (8, 9))

# %%
def f4(*b):
    '''I'm using *args'''
    return 1,2,4,5,[1,4,6],(8,9)

# %%
f4()
# Out:
# (1, 2, 4, 5, [1, 4, 6], (8, 9))

# %%
def f5(p,q,r,s , *m):
    return p , q, r,s, m

# %%
f5(1,4,5,3,6,5,7,10,7)
# Out:
# (1, 4, 5, 3, (6, 5, 7, 10, 7))

# %%
def f5(*x, p,q,r,s ):
    return  x, p , q, r,s

# %%
f5(1,2,4,5,[1,4,6],(8,9))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 f5(1,2,4,5,[1,4,6],(8,9))
#
# TypeError: f5() missing 4 required keyword-only arguments: 'p', 'q', 'r', and 's'

# %%
f5(1,2,4,5, p=[1,4,6], q=(8,9) , r=8,s=0)
# Out:
# ((1, 2, 4, 5), [1, 4, 6], (8, 9), 8, 0)

# %%
def multiply(a,b):
    return a * b

# %%
multiply(2,3)
# Out:
# 6

# %%
def multiply(a,b,c):
    return a * b*c

# %%
multiply(2,3,6)
# Out:
# 36

# %%
def multiply(*args):
    product = 1
    for i in args:
        product = product * i
    
    return product

# %%
res = multiply(1,2,3,6,8)
res
# Out:
# 288

# %%
res = multiply(1,2,3,6,8,6,3,6,9,2,4)
res
# Out:
# 2239488

# %% [markdown]
# ## ** Kwargs:
# When We don't know, how many keyword arguments are going to pass in te a function is called **kwargs.
# **kwargs allows us to pass any number of keyword arguments.
#
# Keyword arguments mean that they contain a key-value pair, like a Python dictionary.

# %%
def f6(**kwargs):
    return kwargs

# %%
f6(b = 4,c = 5,d =  6,e = 6 , n = [3,4,45,5,6,6,6],f="ravi")
# Out:
# {'b': 4, 'c': 5, 'd': 6, 'e': 6, 'n': [3, 4, 45, 5, 6, 6, 6], 'f': 'ravi'}

# %%
def f17(**kwargs):
    return kwargs.values()

# %%
f17(b = 4,c = 5,d =  6,e = 6 , n = [3,4,45,5,6,6,6])
# Out:
# dict_values([4, 5, 6, 6, [3, 4, 45, 5, 6, 6, 6]])

# %%
def f117(**kwargs):
    return list(kwargs.values())

# %%
f117(b = 4,c = 5,d =  6,e = 6 , n = [3,4,45,5,6,6,6])
# Out:
# [4, 5, 6, 6, [3, 4, 45, 5, 6, 6, 6]]

# %%
def f1117(**kwargs):
    return list(kwargs.keys())

# %%
f1117(b = 4,c = 5,d =  6,e = 6 , n = [3,4,45,5,6,6,6])
# Out:
# ['b', 'c', 'd', 'e', 'n']

# %%
def f11117(**kwargs):
  return kwargs

# %%
f11117({'b': 4, 'c': 5, 'd': 6, 'e': 6, 'n': [3, 4, 45, 5, 6, 6, 6]})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 f11117({'b': 4, 'c': 5, 'd': 6, 'e': 6, 'n': [3, 4, 45, 5, 6, 6, 6]})
#
# TypeError: f11117() takes 0 positional arguments but 1 was given

# %% [markdown]
# -> The error is caused because you're passing a dictionary as a positional argument to the function f11117(), but the function is defined to only accept keyword arguments (**kwargs).

# %%
def display(**kwargs):
    for (key,val) in kwargs.items():
        print(f"{key} -> {val}")

# %%
display(india="Delhi", Bangladesh="Dhaka", srilanka="colombo")
# Out:
# india -> Delhi
# Bangladesh -> Dhaka
# srilanka -> colombo

# %%
def fa117(**kwargs):
    return list(kwargs.items())

# %%
fa117(b = 4,c = 5,d =  6,e = 6 , n = [3,4,45,5,6,6,6])
# Out:
# [('b', 4), ('c', 5), ('d', 6), ('e', 6), ('n', [3, 4, 45, 5, 6, 6, 6])]

# %%
def f7(**lax):
    return lax

# %%
f7(b = 4,c = 5,d =  6,e = 6 , n = [3,4,45,5,6,6,6])
# Out:
# {'b': 4, 'c': 5, 'd': 6, 'e': 6, 'n': [3, 4, 45, 5, 6, 6, 6]}

# %%
def f9(*m , **s) :
    return m , s

# %%
f9(1,2,4,5, p=[1,4,6], q=(8,9) , r=8,s=0)
# Out:
# ((1, 2, 4, 5), {'p': [1, 4, 6], 'q': (8, 9), 'r': 8, 's': 0})

# %% [markdown]
# - Scope

# %%
def my_fun():
    x =10 
    print(x)

my_fun()
print(x)
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3     print(x)
#       5 my_fun()
# ----> 6 print(x)
#
# NameError: name 'x' is not defined

# %%
print(x)
# Out:
# 10

# %%
def my_fun():
    x =10 
    x+=1
    print(x)

my_fun()
# Out:
# 11

# %%
# enclosing scope 

def my_fun1():

    x = 10 
 
    def my_fun():
        
        print(x)
    
        

    my_fun()

my_fun1()
# Out:
# 10

# %%
def my_fun1():

    x = 10
    print(y)
 
    def my_fun():
        y=20
        print(x)
    
        

    my_fun()

my_fun1()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 14
#       8         print(x)
#      12     my_fun()
# ---> 14 my_fun1()
#
# Cell In[67], line 4, in my_fun1()
#       1 def my_fun1():
#       3     x = 10
# ----> 4     print(y)
#       6     def my_fun():
#       7         y=20
#
# NameError: name 'y' is not defined

# %%
def my_fun1():

    x = 10
    
 
    def my_fun():
        y=20
        print(x)
    
        

    my_fun()

my_fun1()
print(y)
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 15
#      12     my_fun()
#      14 my_fun1()
# ---> 15 print(y)
#
# NameError: name 'y' is not defined

# %%
def my_fun1():

    x = 10
    
 
    def my_fun():
        y=20
        print(x)
    
        

    my_fun()

my_fun1()
# Out:
# 10

# %%
# global variable 
y=20
def my_fun():
    x =10 
  
    print(x)
     
    print(y)

my_fun()
# Out:
# 10
# 20

# %%
y=20
def my_fun():
    x =10 
  
    print(x)
    
    y+=1 
    print(y)

my_fun()
# Out:
# 10
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[71], line 10
#       7     y+=1
#       8     print(y)
# ---> 10 my_fun()
#
# Cell In[71], line 7, in my_fun()
#       3 x =10
#       5 print(x)
# ----> 7 y+=1
#       8 print(y)
#
# UnboundLocalError: cannot access local variable 'y' where it is not associated with a value

# %%
y=20
def my_fun():
    x =10 
  
    print(x)
    global y
    y+=1 
    print(y)

my_fun()
# Out:
# 10
# 21

# %%
def my_fun(s):
    l=len(s)
    print(s)
    print(l)
    
  

my_fun("laxman")
# Out:
# laxman
# 6

# %%
# global variable 
y=20
def my_fun():
    x =10 
  
    print(x)
    global y
    y+=1
    print(y)

my_fun()
# Out:
# 10
# 21

# %%
def my_fun1():

    x = 10 
 
    def my_fun():
        y=20
        
        x +=1
        print(x)
        
        print(y)
    
        

    my_fun()

my_fun1()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[75], line 17
#      11         print(y)
#      15     my_fun()
# ---> 17 my_fun1()
#
# Cell In[75], line 15, in my_fun1()
#       9     print(x)
#      11     print(y)
# ---> 15 my_fun()
#
# Cell In[75], line 8, in my_fun1.<locals>.my_fun()
#       5 def my_fun():
#       6     y=20
# ----> 8     x +=1
#       9     print(x)
#      11     print(y)
#
# UnboundLocalError: cannot access local variable 'x' where it is not associated with a value

# %%
def my_fun1():

    x = 10 
 
    def my_fun():
        y=20
        global x
        x +=1
        print(x)
        
        print(y)
    
        

    my_fun()

my_fun1()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 17
#      11         print(y)
#      15     my_fun()
# ---> 17 my_fun1()
#
# Cell In[76], line 15, in my_fun1()
#       9     print(x)
#      11     print(y)
# ---> 15 my_fun()
#
# Cell In[76], line 8, in my_fun1.<locals>.my_fun()
#       6 y=20
#       7 global x
# ----> 8 x +=1
#       9 print(x)
#      11 print(y)
#
# NameError: name 'x' is not defined

# %%
def my_fun1():

    x = 10 
 
    def my_fun():
        y=20
        nonlocal x
        x +=1
        print(x)
        
        print(y)
    
        

    my_fun()

my_fun1()
# Out:
# 11
# 20

# %% [markdown]
# ### LEGB Rule Explained
#
# The LEGB rule dictates how Python looks for variable names:
#
# - **L (Local)**: Python first looks for a variable in the **local scope** (inside the current function).
# - **E (Enclosing)**: If not found, it looks in the **enclosing scope** (inside any enclosing functions, in case of nested functions).
# - **G (Global)**: If still not found, it checks the **global scope** (outside the function but in the current module).
# - **B (Built-in)**: Finally, it checks the **built-in scope** for Python’s built-in functions and constants.

# %%
def outer_fun():
    
    x=7
    def innner_fun():
        x =5
        print(x)

    innner_fun()
    print(x)

outer_fun()
# Out:
# 5
# 7

# %%
x=10
def outer_fun():
    
    x=7
    def innner_fun():
        x =5
        print(x)

    innner_fun()
    print(x)

outer_fun()
print(x)
# Out:
# 5
# 7
# 10

# %%
x=10
def outer_fun():
    
    x=7
    def innner_fun():
        
        print(x)

    innner_fun()
    print(x)

outer_fun()
print(x)
# Out:
# 7
# 7
# 10

# %%
x=10
def outer_fun():
    
    
    def innner_fun():
        
        print(x)

    innner_fun()
    print(x)

outer_fun()
print(x)
# Out:
# 10
# 10
# 10

# %% [markdown]
# - Nested Functions

# %%
def outer_fun(outer):

    def inner_fun(inner):
        result =outer + inner
        return result

    result_inner=inner_fun(5)

    return result_inner

result_outer =outer_fun(10)
print(result_outer)
# Out:
# 15

# %%
def sum_of_cubes(a,b):

    def cube(x):
        return x*x*x 


    def add(x,y):
        return x +y
    

    return add( cube(a) ,cube(b))




result = sum_of_cubes(2,3)
print(result)
# Out:
# 35

# %% [markdown]
# - # fucntion can be reuturn fucntion

# %%
def hello():
    def hello1(a):
        return a**2

    return hello1

hello()(3)
# Out:
# 9

# %% [markdown]
# - # fucntion as argument

# %%
def operation(a,b,oper):

    return oper(a,b)
    
    def add(a,b):
        return a+b

    def mul(a,b):
        return a*b

operation(2,3,add)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 11
#       8     def mul(a,b):
#       9         return a*b
# ---> 11 operation(2,3,add)
#
# NameError: name 'add' is not defined
